# %%
import numpy as np
import pandas as pd
import re
import pytesseract
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import os
from colorama import Fore, Style
import matplotlib.colors as mcolors
import matplotlib.patches as mpatch

# %%
image= cv2.imread('Aadhaar card.jpg')
plt.imshow(image)
plt.show()

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text=pytesseract.image_to_string(image)

# %%
print(text)
# Out:
# x
#
# OS MOB
#
# a
#
# ’
#
# District: Shimoga,
#
# Jog Falls,
#
# Gowda,
# Work Men Block Post Office Line
#
# Sagar Taluku
#
# Dp
# WwW
# 65 <
# Rk¢
# Pp
# Pp
# B:
#
# Oe 3
# Rakshith J
# S/O: Jayaraj
# #F 15
# TC: Jog Falls
# PO: Jog Falls
# Sub District: Sagar
# State: Karnataka,
# PIN Code: 577435,
# Mobile: 9449170649
# UM 00 | 1
# UA025079050IN
# Rakshith J
# an, Oae08 / DOB : 17/12/1995
# ame / MALE
# 2632 1417
# apiey
#
# To
# V
#
# 2632 1417 6198
# 3a emo’, 83 Mba
#
# €
#
# —
#
# VN, &
#
# 02/90/+0 SLvvOlLc8L

# %%
res=text.split()

# %%
res
# Out:
# ['x',
#  'OS',
#  'MOB',
#  'a',
#  '’',
#  'District:',
#  'Shimoga,',
#  'Jog',
#  'Falls,',
#  'Gowda,',
#  'Work',
#  'Men',
#  'Block',
#  'Post',
#  'Office',
#  'Line',
#  'Sagar',
#  'Taluku',
#  'Dp',
#  'WwW',
#  '65',
#  '<',
#  'Rk¢',
#  'Pp',
#  'Pp',
#  'B:',
#  'Oe',
#  '3',
#  'Rakshith',
#  'J',
#  'S/O:',
#  'Jayaraj',
#  '#F',
#  '15',
#  'TC:',
#  'Jog',
#  'Falls',
#  'PO:',
#  'Jog',
#  'Falls',
#  'Sub',
#  'District:',
#  'Sagar',
#  'State:',
#  'Karnataka,',
#  'PIN',
#  'Code:',
#  '577435,',
#  'Mobile:',
#  '9449170649',
#  'UM',
#  '00',
#  '|',
#  '1',
#  'UA025079050IN',
#  'Rakshith',
#  'J',
#  'an,',
#  'Oae08',
#  '/',
#  'DOB',
#  ':',
#  '17/12/1995',
#  'ame',
#  '/',
#  'MALE',
#  '2632',
#  '1417',
#  'apiey',
#  'To',
#  'V',
#  '2632',
#  '1417',
#  '6198',
#  '3a',
#  'emo’,',
#  '83',
#  'Mba',
#  '€',
#  '—',
#  'VN,',
#  '&',
#  '02/90/+0',
#  'SLvvOlLc8L']

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image= cv2.imread('Aadhaar-card.jpg')
plt.imshow(image)
plt.show()

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
text=pytesseract.image_to_string(image)

# %%
print(text)
# Out:
# x
#
# | ~o0S Vsord
# Government of India
#
# Ode
#
# 2632 1417 6198
#
# a SAI, Na MOS)
#
# 6, Sae08 / DOB : 17/12/1995
#
# Rakshith J
# aaa / MALE
#
# o
#
# SS

# %%
res=text.split()

# %%
res
# Out:
# ['x',
#  '|',
#  '~o0S',
#  'Vsord',
#  'Government',
#  'of',
#  'India',
#  'Ode',
#  '2632',
#  '1417',
#  '6198',
#  'a',
#  'SAI,',
#  'Na',
#  'MOS)',
#  '6,',
#  'Sae08',
#  '/',
#  'DOB',
#  ':',
#  '17/12/1995',
#  'Rakshith',
#  'J',
#  'aaa',
#  '/',
#  'MALE',
#  'o',
#  'SS']

# %%
index =res.index('Gender:')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 index =res.index('Gender:')
#
# ValueError: 'Gender:' is not in list

# %%
uid= res[index+2] + ' ' + res[index+3] + ' ' + res[index+4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 uid= res[index+2] + ' ' + res[index+3] + ' ' + res[index+4]
#
# NameError: name 'index' is not defined

# %%
uid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 uid
#
# NameError: name 'uid' is not defined
